# %%
import requests
import json
import xml.etree.ElementTree as ET
from time import gmtime, strftime, sleep
import time
import datetime
import boto3
from multiprocessing import Pool

ns = '{http://www.volby.cz/prezident/}'
s3 = boto3.client('s3')

# %%
kandidati = {
    '1': 'Mirek Topolánek',
    '2': 'Michal Horáček',
    '3': 'Pavel Fischer',
    '4': 'Jiří Hynek',
    '5': 'Petr Hannig',
    '6': 'Vratislav Kulhánek',
    '7': 'Miloš Zeman',
    '8': 'Marek Hilšer',
    '9': 'Jiří Drahoš'
}

# %%
while True:
    now = str(datetime.datetime.utcnow().isoformat()) + 'Z'
    print(now)
    r = requests.get('http://80.188.53.60/pls/prezmedia/vysledky_zahranici?kolo=')
    root = ET.fromstring(r.text)

    data = {'UPDATED': now}

    for kont in root[0].findall(ns + 'KONTINENT'):
        for stat in kont.findall(ns + 'STAT'):
            out = {'KAND': {}}
            stat_id = stat.attrib['ZKRATKA']
            out.update(stat.attrib)
            out.update(stat.find(ns + 'UCAST').attrib)
            
            for kn in stat.findall(ns + 'HODN_KAND'):
                kn_id = kn.attrib['PORADOVE_CISLO']

                out['KAND'][kn_id] = kn.attrib
                out['KAND'][kn_id].update({'JMENO': kandidati[kn.attrib['PORADOVE_CISLO']]})

            print(stat_id + ' | ' + strftime("%Y-%m-%d %H_%M_%S", time.localtime())) 
            putFile = s3.put_object(Bucket='prezident17', 
                            Key='kolo1/obce/' + stat_id + '.json', 
                            Body=json.dumps(out), 
                            ACL='public-read', 
                            ContentType='application/json')
    time.sleep(45)
    break #remove before flight
# Out:
# 2017-12-19T15:25:21.489504Z
# DZ | 2017-12-19 16_25_21
# EG | 2017-12-19 16_25_22
# ET | 2017-12-19 16_25_22
# GH | 2017-12-19 16_25_22
# KE | 2017-12-19 16_25_22
# MA | 2017-12-19 16_25_22
# NG | 2017-12-19 16_25_22
# SN | 2017-12-19 16_25_22
# TN | 2017-12-19 16_25_22
# ZA | 2017-12-19 16_25_22
# ZM | 2017-12-19 16_25_22
# AR | 2017-12-19 16_25_22
# BR | 2017-12-19 16_25_22
# CA | 2017-12-19 16_25_22
# CL | 2017-12-19 16_25_22
# CO | 2017-12-19 16_25_22
# CU | 2017-12-19 16_25_22
# MX | 2017-12-19 16_25_22
# PE | 2017-12-19 16_25_23
# US | 2017-12-19 16_25_23
# AU | 2017-12-19 16_25_23
# AE | 2017-12-19 16_25_23
# AF | 2017-12-19 16_25_23
