# %%
import requests
import json
import xml.etree.ElementTree as ET
from time import gmtime, strftime, sleep
import time
import datetime
import boto3
from var import *

ns = '{http://www.volby.cz/prezident/}'
s3 = boto3.client('s3')

# %%
kandidati = {
    '1': 'Mirek Topolánek',
    '2': 'Michal Horáček',
    '3': 'Pavel Fischer',
    '4': 'Jiří Hynek',
    '5': 'Petr Hannig',
    '6': 'Vratislav Kulhánek',
    '7': 'Miloš Zeman',
    '8': 'Marek Hilšer',
    '9': 'Jiří Drahoš'
}

# %%
while True:
    now = str(datetime.datetime.utcnow().isoformat()) + 'Z'
    print(now)
    r = requests.get(endpoint + '/pls/prezmedia/vysledky_zahranici?kolo=')
    root = ET.fromstring(r.text)

    data = {'UPDATED': now}

    for kont in root[0].findall(ns + 'KONTINENT'):
        for stat in kont.findall(ns + 'STAT'):
            out = {'KAND': {}}
            stat_id = stat.attrib['ZKRATKA']
            out.update(stat.attrib)
            out.update(stat.find(ns + 'UCAST').attrib)
            
            for kn in stat.findall(ns + 'HODN_KAND'):
                kn_id = kn.attrib['PORADOVE_CISLO']

                out['KAND'][kn_id] = kn.attrib
                out['KAND'][kn_id].update({'JMENO': kandidati[kn.attrib['PORADOVE_CISLO']]})

            print(stat_id + ' | ' + strftime("%Y-%m-%d %H_%M_%S", time.localtime())) 
            putFile = s3.put_object(Bucket='prezident17', 
                            Key='kolo' + kolo + '/obce/' + stat_id + '.json', 
                            Body=json.dumps(out), 
                            ACL='public-read', 
                            ContentType='application/json')
    time.sleep(45)
    break #remove before flight
# Out:
# 2018-01-04T09:11:55.352880Z
# DZ | 2018-01-04 10_11_55
# EG | 2018-01-04 10_11_55
# ET | 2018-01-04 10_11_56
# GH | 2018-01-04 10_11_56
# KE | 2018-01-04 10_11_56
# MA | 2018-01-04 10_11_56
# NG | 2018-01-04 10_11_56
# SN | 2018-01-04 10_11_56
# TN | 2018-01-04 10_11_56
# ZA | 2018-01-04 10_11_56
# ZM | 2018-01-04 10_11_56
# AR | 2018-01-04 10_11_56
# BR | 2018-01-04 10_11_56
# CA | 2018-01-04 10_11_56
# CL | 2018-01-04 10_11_56
# CO | 2018-01-04 10_11_57
# CU | 2018-01-04 10_11_57
# MX | 2018-01-04 10_11_57
# PE | 2018-01-04 10_11_57
# US | 2018-01-04 10_11_57
# AU | 2018-01-04 10_11_57
# AE | 2018-01-04 10_11_57
# AF | 2018-01-04 10_11_57
# AM | 2018-01-04 10_11_57
# AZ | 2018-01-04 10_11_57
# CN | 2018-01-04 10_11_57
# CY | 2018-01-04 10_11_57
# GE | 2018-01-04 10_11_57
# ID | 2018-01-04 10_11_57
# IL | 2018-01-04 10_11_57
# IN | 2018-01-04 10_11_57
# IQ | 2018-01-04 10_11_58
# IR | 2018-01-04 10_11_58
# JO | 2018-01-04 10_11_58
# JP | 2018-01-04 10_11_58
# KH | 2018-01-04 10_11_58
# KP | 2018-01-04 10_11_58
# KR | 2018-01-04 10_11_58
# KW | 2018-01-04 10_11_58
# KZ | 2018-01-04 10_11_58
# LB | 2018-01-04 10_11_58
# MM | 2018-01-04 10_11_58
# MN | 2018-01-04 10_11_58
# MY | 2018-01-04 10_11_58
# PH | 2018-01-04 10_11_58
# PK | 2018-01-04 10_11_58
# SA | 2018-01-04 10_11_58
# SY | 2018-01-04 10_11_58
# TH | 2018-01-04 10_11_58
# TR | 2018-01-04 10_11_59
# UZ | 2018-01-04 10_11_59
# VN | 2018-01-04 10_11_59
# AL | 2018-01-04 10_11_59
# AT | 2018-01-04 10_11_59
# BA | 2018-01-04 10_11_59
# BE | 2018-01-04 10_11_59
# BG | 2018-01-04 10_11_59
# BY | 2018-01-04 10_11_59
# CH | 2018-01-04 10_11_59
# DE | 2018-01-04 10_11_59
# DK | 2018-01-04 10_11_59
# EE | 2018-01-04 10_11_59
# ES | 2018-01-04 10_11_59
# FI | 2018-01-04 10_11_59
# FR | 2018-01-04 10_11_59
# GB | 2018-01-04 10_11_59
# GR | 2018-01-04 10_12_00
# HR | 2018-01-04 10_12_00
# HU | 2018-01-04 10_12_00
# IE | 2018-01-04 10_12_00
# IT | 2018-01-04 10_12_00
# KO | 2018-01-04 10_12_00
# LT | 2018-01-04 10_12_00
# LU | 2018-01-04 10_12_00
# LV | 2018-01-04 10_12_00
# MD | 2018-01-04 10_12_00
# ME | 2018-01-04 10_12_00
# MK | 2018-01-04 10_12_00
# NL | 2018-01-04 10_12_00
# NO | 2018-01-04 10_12_00
# PL | 2018-01-04 10_12_00
# PT | 2018-01-04 10_12_00
# RO | 2018-01-04 10_12_00
# RS | 2018-01-04 10_12_01
# RU | 2018-01-04 10_12_01
# SE | 2018-01-04 10_12_01
# SI | 2018-01-04 10_12_01
# SK | 2018-01-04 10_12_01
# UA | 2018-01-04 10_12_01
# VA | 2018-01-04 10_12_01
